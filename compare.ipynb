# %%
import pandas as pd
from operator import itemgetter
import numpy as np

dfs = pd.read_csv('us-city-data.csv')
dfc = pd.read_csv('country-data.csv')

# %%
#Sort by the metric you want to compare to
#Choices are:
# Captial City Pop
# Largest City Pop
# Population
# mi2_total
# km2_total
# mi2_land
# km2_land
# mi2_water
# km2_water
# % water
def sortBy(metric):
    s = []
    c = []
    dfct = dfc[~dfc[metric].isnull()]
    dfct.reset_index(inplace=True)
    
    for label, content in dfs.iterrows():
        s.append([dfs.iloc[label][metric],dfs.iloc[label]["State"]]) 
    s.sort(key=itemgetter(0), reverse=True)
    
    for label, content in dfct.iterrows():
        c.append([dfct.iloc[label][metric],dfct.iloc[label]["Country"]]) 
    c.sort(key=itemgetter(0), reverse=True)
    
    return s, c

# %%
def compare(metric):
    sortedState, sortedCountry = sortBy(metric)
    for i in range(len(sortedState)):
        if i != len(sortedState)-1:
            t = (sortedState[i][0] + sortedState[i+1][0]) / 2
        else:
            t = 0
        print('\n'+sortedState[i][1]+": "+str(sortedState[i][0])+'\n')
        while sortedCountry[0][0] > t:
            print("   "+str(sortedCountry[0][1]) +
                  ": "+str(sortedCountry[0][0]))
            sortedCountry.remove(sortedCountry[0])
            if sortedCountry == []:
                break

# %%
compare('Capital City Pop')
# Out:
# Arizona: 1445632
#
#    Japan: 13185502.0
#    Iran: 12223598.0
#    Indonesia: 10187595.0
#    Thailand: 8249117.0
#    United Kingdom: 8174100.0
#    Colombia: 7613303.0
#    Peru: 7605742.0
#    Egypt: 7438376.0
#    Turkey: 4890893.0
#    Saudi Arabia: 4878723.0
#    Democratic Republic of the Congo: 4385264.0
#    Vietnam: 3398889.0
#    Spain: 3233527.0
#    Dominican Republic: 2995211.0
#    Ukraine: 2832398.0
#    Italy: 2792508.0
#    Kenya: 2665657.0
#    Brazil: 2648532.0
#    Taiwan: 2618772.0
#    Angola: 2453779.0
#    South Africa: 2345908.0
#    France: 2268265.0
#    Uzbekistan: 2207850.0
#    Cuba: 2135498.0
#    Romania: 1942254.0
#    Madagascar: 1918117.0
#    Azerbaijan: 1879251.0
#    Venezuela: 1838939.0
#    Morocco: 1789635.0
#    Hungary: 1728718.0
#    Poland: 1706724.0
#    Uganda: 1659600.0
#    Philippines: 1652171.0
#    Ghana: 1640507.0
#    Lebanon: 1574387.0
#    Austria: 1552789.0
#    Ecuador: 1504991.0
#    Yemen: 1431649.0
#    Guinea: 1399981.0
#    Malaysia: 1381830.0
#    Uruguay: 1369797.0
#    Zambia: 1331254.0
#    Mali: 1289626.0
#    Haiti: 1235227.0
#    Denmark: 1231166.0
#    Denmark: 1231166.0
#    Czech Republic: 1227332.0
#    Kuwait: 1171880.0
#    Serbia: 1154589.0
#
# Indiana: 829718
#
#    Armenia: 1121900.0
#    Guatemala: 1103865.0
#    Pakistan: 955629.0
#    Nicaragua: 926883.0
#    Mongolia: 907802.0
#    Malawi: 902388.0
#    Canada: 898150.0
#    Mexico: 885180.0
#    Kyrgyzstan: 843240.0
#
# Ohio: 822553
#
#    Togo: 824738.0
#
# Texas: 790390
#
#    Croatia: 804200.0
#    Niger: 794814.0
#    Moldova: 794800.0
#    Israel: 780200.0
#    Nigeria: 778567.0
#    Sweden: 770284.0
#    Tunisia: 767629.0
#    Albania: 763634.0
#    Turkmenistan: 763537.0
#    Chad: 751288.0
#    Honduras: 735982.0
#    Central African Republic: 731548.0
#    Iraq: 721640.0
#    Greece: 721477.0
#    Mauritania: 719167.0
#    Rwanda: 718414.0
#
# Tennessee: 635710
#
#
# Massachusetts: 617594
#
#
# Colorado: 600158
#
#    United States: 601723.0
#    Finland: 596661.0
#
# Oklahoma: 580000
#
#    Tajikistan: 582496.0
#    Norway: 575475.0
#    Portugal: 564657.0
#    Lithuania: 556723.0
#    Gabon: 556425.0
#    Eritrea: 543707.0
#
# California: 466488
#
#    El Salvador: 521366.0
#    Paraguay: 520722.0
#    Djibouti: 475332.0
#    Guinea-Bissau: 452640.0
#
# Georgia: 420003
#
#    Slovakia: 424207.0
#
# North Carolina: 403892
#
#    Estonia: 403547.0
#    Burundi: 384461.0
#    Bosnia and Herzegovina: 383604.0
#    New Zealand: 381900.0
#
# Hawaii: 337256
#
#    Australia: 354644.0
#    Ethiopia: 340740.0
#    Costa Rica: 328195.0
#
# Minnesota: 300851
#
#    Papua New Guinea: 307643.0
#    Bolivia: 300000.0
#    India: 292300.0
#    Argentina: 289182.0
#    Laos: 287579.0
#    Tanzania: 287200.0
#    Slovenia: 280140.0
#
# Nebraska: 258379
#
#    Lesotho: 267652.0
#    Suriname: 254147.0
#    Namibia: 252721.0
#
# Wisconsin: 233209
#
#    Cyprus: 239277.0
#
# Louisiana: 229553
#
#    Botswana: 225656.0
#    Benin: 223552.0
#
# Alabama: 205764
#
#    Cambodia: 211725.0
#
# Idaho: 205671
#
#
# Virginia: 204214
#
#
# Iowa: 203433
#
#    China: 201800.0
#
# Arkansas: 193524
#
#    Somalia: 197133.0
#    Western Sahara: 194668.0
#    East Timor: 193563.0
#
# Florida: 190894
#
#    Bulgaria: 190295.0
#
# Utah: 186440
#
#
# Rhode Island: 178042
#
#    Belgium: 180790.0
#    Mozambique: 176689.0
#
# Mississippi: 173514
#
#    Belarus: 170261.0
#    Sierra Leone: 170200.0
#
# Oregon: 154637
#
#    Zimbabwe: 148728.0
#    Mauritius: 147251.0
#    Ireland: 145769.0
#    Georgia: 144993.0
#
# South Carolina: 131686
#
#    Montenegro: 141854.0
#    Bahrain: 140616.0
#    Guyana: 134599.0
#    Senegal: 130594.0
#
# Kansas: 127473
#
#
# Connecticut: 124775
#
#    Cape Verde: 125464.0
#    Switzerland: 121631.0
#
# Illinois: 116250
#
#    Sri Lanka: 118556.0
#    Libya: 118445.0
#    Russia: 115410.0
#
# Michigan: 114297
#
#    Liberia: 110970.0
#
# New York: 97856
#
#    Maldives: 103693.0
#    Bhutan: 101259.0
#    Equatorial Guinea: 100677.0
#    Barbados: 96578.0
#
# New Jersey: 84913
#
#    Fiji: 84410.0
#    Panama: 81397.0
#    Nepal: 81226.0
#
# New Mexico: 75764
#
#    Luxembourg: 76420.0
#    Latvia: 71316.0
#    Bangladesh: 70940.0
#    Jamaica: 70163.0
#
# North Dakota: 61272
#
#
# Wyoming: 59466
#
#    Comoros: 60200.0
#    Solomon Islands: 59288.0
#    United Arab Emirates: 58597.0
#    Chile: 58438.0
#
# Nevada: 55274
#
#
# West Virginia: 51400
#
#    Singapore: 53120.0
#    Trinidad and Tobago: 50479.0
#
# Pennsylvania: 49528
#
#
# Washington: 46478
#
#
# Missouri: 43079
#
#
# New Hampshire: 42695
#
#
# Maryland: 38394
#
#    Samoa: 39813.0
#
# Delaware: 36047
#
#    Monaco: 35986.0
#    Algeria: 35740.0
#    Germany: 35200.0
#    Syria: 35000.0
#
# Alaska: 32468
#
#    Afghanistan: 32890.0
#
# Montana: 28190
#
#    Seychelles: 29298.0
#    Brunei: 28135.0
#
# Kentucky: 25527
#
#    Marshall Islands: 25400.0
#    Andorra: 22884.0
#    Antigua and Barbuda: 22679.0
#    Tonga: 22400.0
#
# Maine: 19136
#
#
# South Dakota: 13646
#
#    Cameroon: 16160.0
#    Burkina Faso: 15231.0
#    Dominica: 14847.0
#    Qatar: 14500.0
#    Belize: 12300.0
#
# Vermont: 7855
#
#    Oman: 7970.0
#    Grenada: 7500.0
#    Kazakhstan: 7000.0
#    Malta: 6315.0
#    Liechtenstein: 5248.0
#    San Marino: 4493.0
#    Tuvalu: 4492.0
#    Iceland: 1150.0
#    Nauru: 1100.0
#    Palau: 391.0
#    Vanuatu: 380.0
#    Kiribati: 300.0
